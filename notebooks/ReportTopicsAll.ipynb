# %% [markdown]
# # All participatory spaces

# %%
import pandas as pd
import matplotlib.pyplot as plt

DATA_PATH = '../data/public/'
VOCAB_FILE = DATA_PATH + 'vocabulario-controlado-basico-vcb-lista-alfabetica.txt'
BERT_RESULTS_FILE = DATA_PATH + 'results_TopicClassification_BERT_CosineSimilarity.csv'
TDIDF_RESULTS_FILE = DATA_PATH + 'results_TopicClassification_TFIDF_CosineSimilarity.csv'

# %% [markdown]
# ### Get and Process the Controlled Vocabulary

# %%
def process_vocab_file(vocab_file):
    ROWS_TO_SKIP = 8
    vocab_dict = {}
    with open(vocab_file, 'r', encoding='utf-8') as file:
        current_term = ''
        for line in file.read().splitlines()[ROWS_TO_SKIP:]:
            if not line.startswith('\t') and line != '':
                current_term = line
                vocab_dict[current_term] = {
                    'USE': [], # Use
                    'DF': [],  # Definição
                    'UP': [],  # Termos não preferenciais
                    'TG': [],  # Termo geral
                    'TR': [],  # Termos relacionados
                    'TE': [],  # Termos específicos
                    'EQ': [],  # Equivalente
                    'Nota de escopo': [],
                }
            elif line != '':
                property = line.strip().split(':')
                key = property[0].strip()
                value = property[1].strip()
                vocab_dict[current_term][key].append(value)
    return vocab_dict
vocab_json = process_vocab_file(vocab_file=VOCAB_FILE)
vocab_json
# Out:
# {'2019-nCoV disease': {'USE': ['Covid-19'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  '2FA': {'USE': ['Autenticação de dois fatores'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  '2Factor Authentication': {'USE': ['Autenticação de dois fatores'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'AAE': {'USE': ['Avaliação ambiental estratégica'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ab-rogação': {'USE': [],
#   'DF': ['É a revogação total de uma lei pela edição de uma nova. Lê-se lei em sentido amplo, abrangendo os decretos e demais regulamentos que também poderão sofrer ab-rogação. É também considerado o ato de tornar nulo ou sem efeito a norma jurídica anterior.$uhttps'],
#   'UP': ['Revogação total'],
#   'TG': ['Revogação de legislação'],
#   'TR': ['Derrogação',
#    'Irretroatividade das leis',
#    'Norma jurídica',
#    'Repristinação',
#    'Retroatividade das leis'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abacate': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Fruta tropical'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abacaxi': {'USE': [],
#   'DF': [],
#   'UP': ['Ananás'],
#   'TG': ['Fruta tropical'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abalo sísmico': {'USE': ['Terremoto'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abalroamento aéreo': {'USE': ['Acidente aeronáutico'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abalroamento de navios': {'USE': ['Acidente marítimo'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abancainos': {'USE': [],
#   'DF': ['Naturais da ou relativos à região de(a)(o) Abancay'],
#   'UP': [],
#   'TG': ['Etnologia, Abancay', 'Grupos nacionais'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abandono (Direito marítimo)': {'USE': ['Direito de abandono'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abandono afetivo': {'USE': [],
#   'DF': ['Omissão dos pais ou de um deles, pelo menos relativamente ao dever de educação, entendida esta na sua acepção mais ampla, permeada de afeto, carinho, atenção, desvelo, conforme preconizado na Constituição Federal (art. 227), no Estatuto da Criança e do Adolescente (art. 22) e no Código civil (art. 1.566).'],
#   'UP': ['Omissão do afeto'],
#   'TG': ['Relações familiares'],
#   'TR': ['Abandono intelectual',
#    'Abandono material',
#    'Assistência ao menor',
#    'Dano existencial',
#    'Dano moral',
#    'Direito ao afeto',
#    'Direitos do menor',
#    'Maternidade',
#    'Menor',
#    'Pais e filhos',
#    'Paternidade',
#    'Vida familiar'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abandono da causa': {'USE': [],
#   'DF': ['Situação que se verifica quando o processo fica paralisado por mais de um ano, em virtude de negligência das partes - autor ou réu -, ou por mais de trinta dias, por negligência do autor. - Ver Artigo 485, II e III, do CPC/2015.$vTesauro jurídico do STF'],
#   'UP': ['Abandono do processo'],
#   'TG': ['Processo civil'],
#   'TR': ['Desídia', 'Desistência (processo civil)', 'Extinção do processo'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abandono da coisa': {'USE': [],
#   'DF': ['Ato voluntário pelo qual alguém abdica da posse e\xa0propriedade de uma coisa, por não querê-la mais (CC, arts. 520, I, 589, III e 592, parágrafo único)$uhttp'],
#   'UP': ['Abandono de imóvel'],
#   'TG': ['Ato jurídico'],
#   'TR': ['Bens imóveis',
#    'Direito de propriedade',
#    'Propriedade',
#    'Transmissão de propriedade'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abandono de cargo': {'USE': [],
#   'DF': ['Lei 8.112/1990'],
#   'UP': ['Abandono de função',
#    'Abandono de função pública',
#    'Abandono do cargo'],
#   'TG': ['Crime praticado por funcionário público contra a administração em geral'],
#   'TR': ['Abandono de emprego', 'Cargo público', 'Processo disciplinar'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abandono de emprego': {'USE': [],
#   'DF': ['CLT'],
#   'UP': [],
#   'TG': [],
#   'TR': ['Abandono de cargo',
#    'Demissão',
#    'Despedida por justa causa',
#    'Emprego (teoria econômica)',
#    'Falta grave',
#    'Rescisão contratual'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abandono de função': {'USE': ['Abandono de cargo'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abandono de função pública': {'USE': ['Abandono de cargo'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abandono de imóvel': {'USE': ['Abandono da coisa'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abandono de incapaz': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Periclitação da vida e da saúde'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abandono de posto': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Crime contra o serviço militar'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abandono do cargo': {'USE': ['Abandono de cargo'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abandono do lar': {'USE': [],
#   'DF': ['Abandono de lar é um conceito jurídico usado quando\xa0um dos cônjuges deixa a residência em que o casal vivia. Significa a saída de casa, que acontece por vontade própria (voluntariamente).$uhttps'],
#   'UP': [],
#   'TG': [],
#   'TR': ['Casamento',
#    'Cônjuge',
#    'Família',
#    'Guarda dos filhos',
#    'Separação de fato',
#    'Sociedade conjugal',
#    'Violência doméstica'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abandono do processo': {'USE': ['Abandono da causa'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abandono escolar': {'USE': [],
#   'DF': ['Condição do aluno que deixa de frequentar a escola durante o andamento de determinado ano letivo.$vANUÁRIO Brasileiro da Educação Básica'],
#   'UP': ['Infrequência escolar'],
#   'TG': ['Evasão escolar'],
#   'TR': ['Frequência escolar', 'Matrícula escolar', 'Rendimento escolar'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abandono intelectual': {'USE': [],
#   'DF': ['O crime é tipificado como abandono intelectual e está previsto no artigo 246, caput, do Código Penal, com pena prevista de 15 dias a 1 mês de detenção, ou multa. No Brasil, o ensino é obrigatório entre 4 e 17 anos.$uhttps'],
#   'UP': [],
#   'TG': ['Crime contra a assistência familiar', 'Crime contra a família'],
#   'TR': ['Abandono afetivo',
#    'Assistência ao menor',
#    'Criança',
#    'Direito à educação',
#    'Direitos do menor',
#    'Educação da criança',
#    'Menor abandonado'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abandono liberatório': {'USE': ['Direito de abandono'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abandono material': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Crime contra a assistência familiar', 'Crime contra a família'],
#   'TR': ['Abandono afetivo',
#    'Assistência à velhice',
#    'Assistência ao menor',
#    'Direitos do menor',
#    'Pensão alimentícia'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abastecimento de água': {'USE': [],
#   'DF': ["Abastecimento através de rede geral ou outra forma (água proveniente de chafariz, bica ou mina, poço particular, caminhão-pipa, cursos d'água etc.).$vIBGE. Atlas de saneamento. IBGE. Glossário. Rio de Janeiro"],
#   'UP': ['Água, abastecimento',
#    'Oferta de água',
#    'Sistema de abastecimento de água'],
#   'TG': ['Infraestrutura urbana', 'Serviço de utilidade pública'],
#   'TR': ['Adutora',
#    'Água',
#    'Água canalizada',
#    'Aquífero',
#    'Equipamento urbano',
#    'Estação elevatória',
#    'Fornecimento de água',
#    'Instalação hidráulica',
#    'Manancial',
#    'Recursos hídricos',
#    'Rede de distribuição de água',
#    'Saneamento',
#    'Saneamento ambiental',
#    'Saneamento básico',
#    'Saneamento urbano',
#    'Serviço de água e esgotos',
#    'Serviço de saneamento básico',
#    'Tratamento da água'],
#   'TE': ['Estação de tratamento de água'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abastecimento de armas': {'USE': [],
#   'DF': [],
#   'UP': ['Fornecimento de armas'],
#   'TG': [],
#   'TR': ['Armas', 'Tráfico de arma'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abastecimento de energia': {'USE': ['Distribuição de energia elétrica'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abastecimento de tropas e meios': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Logística'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abastecimento energético': {'USE': ['Distribuição de energia elétrica'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abate': {'USE': ['Abate de animais'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abate animal': {'USE': ['Abate de animais'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abate de animais': {'USE': [],
#   'DF': ['Morte de um animal por sangria.$vMinistério da Agricultura, Pecuária e Abastecimento. Instrução Normativa nº 3, de 17 de janeiro de 2000'],
#   'UP': ['Abate', 'Abate animal', 'Abate de gado'],
#   'TG': ['Ciência e tecnologia de alimentos'],
#   'TR': ['Bem-estar animal',
#    'Crueldade contra animal',
#    'Direito animal',
#    'Frigorífico',
#    'Indústria de carne',
#    'Veganismo',
#    'Vegetarianismo'],
#   'TE': ['Abate humanitário'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abate de gado': {'USE': ['Abate de animais'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abate humanitário': {'USE': [],
#   'DF': ['Procedimentos de abate humanitário'],
#   'UP': ['Abate humanitário de animais', 'Procedimentos de abate humanitário'],
#   'TG': ['Abate de animais'],
#   'TR': ['Crueldade contra animal', 'Direito animal'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abate humanitário de animais': {'USE': ['Abate humanitário'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abatedouro': {'USE': ['Frigorífico'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abdicação de Dom Pedro': {'USE': ['Abdicação de Pedro I (1831)'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abdicação de Pedro I (1831)': {'USE': [],
#   'DF': [],
#   'UP': ['Abdicação de Dom Pedro'],
#   'TG': ['Primeiro Reinado (1822-1831)'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abecásios': {'USE': [],
#   'DF': ['Naturais da ou relativos à região de(a)(o) Abecásia'],
#   'UP': ['Abecázios'],
#   'TG': ['Etnologia, Abecásia'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abecázios': {'USE': ['Abecásios'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abelha': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Inseto'],
#   'TR': ['Apicultura', 'Cera de abelha', 'Mel de abelha'],
#   'TE': ['Abelha africana'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abelha africana': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Abelha'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abelha, criação': {'USE': ['Apicultura'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aberração': {'USE': ['Defeito congênito'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aberratio ictus': {'USE': ['Erro na execução'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abertura comercial': {'USE': [],
#   'DF': ['Redução ou eliminação de barreiras tarifárias, ou outras restrições às importações de caráter não-tarifário (Aladi).'],
#   'UP': ['Liberalização comercial',
#    'Liberalização do comércio',
#    'Liberalização do mercado'],
#   'TG': ['Política comercial'],
#   'TR': ['Abertura econômica',
#    'Comércio exterior',
#    'Comércio internacional',
#    'Globalização da economia',
#    'Livre comércio',
#    'Política tarifária'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abertura da economia': {'USE': ['Abertura econômica'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abertura de capital': {'USE': ['Capital aberto'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abertura de negociação': {'USE': ['Negociação internacional'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abertura econômica': {'USE': [],
#   'DF': ['Decorre de uma ação pragmática de ajustamento da economia, para adquirir maior capacitação de competição com produtos similares importados, em quantidade, qualidade e preços, mesmo com margem de proteção zero ou reduzido imposto de importação. Pressupõe, pois, forte modernização da estrutura produtiva, com redução de custos e permanente crescimento da produtividade. Pressupõe, também, criar condições para ampliar as exportações e conquistar novos mercados (POLÍTICA de comércio exterior, abertura econômica e desenvolvimento industrial'],
#   'UP': ['Abertura da economia',
#    'Liberalização da economia',
#    'Liberalização econômica'],
#   'TG': ['Política econômica internacional'],
#   'TR': ['Abertura comercial', 'Neoliberalismo', 'Política econômica'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abertura política': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': ['Democratização'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abexins': {'USE': ['Abissínios'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abissínios': {'USE': [],
#   'DF': ['Naturais da ou relativos à região de(a)(o) Abissínia'],
#   'UP': ['Abexins'],
#   'TG': ['Etnologia, Abissínia'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'ABNT': {'USE': ['Associação de elaboração de normas'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abóbora': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Hortaliça'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abolição da escravatura': {'USE': ['Abolição da escravidão'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abolição da escravatura (1888)': {'USE': ['Abolição da escravidão (1888)'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abolição da escravidão': {'USE': [],
#   'DF': [],
#   'UP': ['Abolição da escravatura'],
#   'TG': ['Movimento social'],
#   'TR': ['Abolicionismo',
#    'Abolicionista',
#    'Direito à liberdade',
#    'Escravidão',
#    'Escravo'],
#   'TE': ['Abolição da escravidão (1888)'],
#   'EQ': [],
#   'Nota de escopo': ['Usar para abolição da escravidão em diversos países. Ex.']},
#  'Abolição da escravidão (1888)': {'USE': [],
#   'DF': [],
#   'UP': ['Abolição da escravatura (1888)'],
#   'TG': ['Abolição da escravidão'],
#   'TR': ['Abolicionismo',
#    'Abolicionista',
#    'Conjuração Baiana (1798-1799)',
#    'Escravidão no Brasil (1539-1888)',
#    'Escravo',
#    'Quilombo',
#    'Trabalho escravo'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': ['Termo específico para o Brasil. Acrescentar, sempre, o especificador geográfico "Brasil".']},
#  'Abolição de privilégios': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Direito à igualdade'],
#   'TR': ['Mordomia'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abolição do crime': {'USE': ['Abolitio criminis'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abolição do delito': {'USE': ['Abolitio criminis'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abolicionismo': {'USE': [],
#   'DF': [],
#   'UP': ['Movimento abolicionista', 'Movimento antiescravagista'],
#   'TG': ['Movimento social'],
#   'TR': ['Abolição da escravidão',
#    'Abolição da escravidão (1888)',
#    'Abolicionista',
#    'Conjuração Baiana (1798-1799)',
#    'Escravidão',
#    'Escravidão e Igreja',
#    'Escravidão no Brasil (1539-1888)',
#    'Escravo',
#    'Movimento negro',
#    'Tráfico de escravos (1549-1850)'],
#   'TE': ['Abolicionismo (1630-1888)'],
#   'EQ': [],
#   'Nota de escopo': ['Usar para movimentos abolicionistas em diversos países. Para o Brasil, usar o termo mais específico']},
#  'Abolicionismo (1630-1888)': {'USE': [],
#   'DF': [],
#   'UP': ['Movimento abolicionista (1630-1888)'],
#   'TG': ['Abolicionismo'],
#   'TR': ['Bill Aberdeen (1845)',
#    'Escravidão no Brasil (1539-1888)',
#    'Quilombo dos Palmares (1630-1695)'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abolicionismo animal': {'USE': ['Direito animal'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abolicionista': {'USE': [],
#   'DF': ['Pessoa que é adepta ou aliada do abolicionismo e do movimento abolicionista.$uhttp'],
#   'UP': [],
#   'TG': ['Pessoas'],
#   'TR': ['Abolição da escravidão',
#    'Abolição da escravidão (1888)',
#    'Abolicionismo',
#    'Escravidão'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abolitio criminis': {'USE': [],
#   'DF': ['1. Abolição do crime em razão do advento de lei nova que deixa de considerar crime a conduta anteriormente tipificada. 2. CP'],
#   'UP': ['Abolição do crime',
#    'Abolição do delito',
#    'Descriminalização da conduta'],
#   'TG': ['Extinção da punibilidade'],
#   'TR': ['Direito intertemporal',
#    'Lei penal mais benéfica',
#    'Retroatividade das leis'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abono': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Direitos dos trabalhadores'],
#   'TR': ['Renda mínima garantida'],
#   'TE': ['Abono de férias', 'Abono especial'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abono de férias': {'USE': [],
#   'DF': [],
#   'UP': ['Abono pecuniário'],
#   'TG': ['Abono'],
#   'TR': ['Direito a férias periódicas remuneradas', 'Férias', 'Remuneração'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abono de permanência': {'USE': [],
#   'DF': [],
#   'UP': ['Abono de permanência em serviço', 'Abono permanência'],
#   'TG': ['Benefício previdenciário'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abono de permanência em serviço': {'USE': ['Abono de permanência'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abono especial': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Abono'],
#   'TR': ['Assiduidade'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abono pecuniário': {'USE': ['Abono de férias'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abono permanência': {'USE': ['Abono de permanência'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abordagem (direito marítimo)': {'USE': [],
#   'DF': [],
#   'UP': ['Colisão marítima'],
#   'TG': ['Acidente marítimo', 'Direito marítimo', 'Navegação marítima'],
#   'TR': ['Avaria (direito marítimo)'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aborígenes americanos': {'USE': ['Índios'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abortamento': {'USE': ['Aborto (direito penal)'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aborto': {'USE': [],
#   'DF': ['Interrupção da gravidez pela morte do feto ou embrião, junto com os anexos ovulares. Pode ser espontâneo (aborto espontâneo, também conhecido como "miscarriage" em inglês) ou provocado (aborto induzido). O feto expulso com menos de 0,5 kg ou 20 semanas de gestação é considerado abortado (feto abortado).'],
#   'UP': [],
#   'TG': ['Morte fetal', 'Saúde reprodutiva'],
#   'TR': ['Bioética',
#    'Controle da natalidade',
#    'Direito à vida',
#    'Direitos reprodutivos',
#    'Nascimento',
#    'Planejamento familiar',
#    'Saúde da mulher'],
#   'TE': ['Aborto (direito penal)',
#    'Aborto eugênico',
#    'Aborto sentimental',
#    'Aborto social',
#    'Aborto terapêutico'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aborto (direito penal)': {'USE': [],
#   'DF': [],
#   'UP': ['Abortamento',
#    'Gravidez, interrupção',
#    'Interrupção voluntária da gravidez'],
#   'TG': ['Aborto', 'Crime contra a vida'],
#   'TR': ['Anticoncepcional',
#    'Bioética',
#    'Controle da natalidade',
#    'Direito à vida',
#    'Direitos reprodutivos',
#    'Gravidez',
#    'Obstetrícia',
#    'Parto (obstetrícia)',
#    'Planejamento familiar',
#    'Salário-maternidade',
#    'Saúde da mulher'],
#   'TE': ['Aborto provocado pela gestante ou com seu consentimento',
#    'Aborto provocado por terceiro'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aborto eugênico': {'USE': [],
#   'DF': ['Aborto realizado por causa de possíveis defeitos fetais.$vDeCS'],
#   'UP': ['Aborto seletivo', 'Abortos eugênicos', 'Abortos seletivos'],
#   'TG': ['Aborto', 'Cirurgia'],
#   'TR': ['Aborto terapêutico', 'Feto'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aborto necessário': {'USE': ['Aborto terapêutico'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aborto provocado pela gestante ou com seu consentimento': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Aborto (direito penal)'],
#   'TR': ['Aborto social'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aborto provocado por terceiro': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Aborto (direito penal)'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aborto seletivo': {'USE': ['Aborto eugênico'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aborto sentimental': {'USE': [],
#   'DF': ['É o aborto nos casos de estupro.$uhttps'],
#   'UP': [],
#   'TG': ['Aborto'],
#   'TR': ['Aborto terapêutico', 'Estupro', 'Incesto'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aborto social': {'USE': [],
#   'DF': ['É o aborto feito por falta de recursos financeiros, em outras palavras, ocorre quando a mãe não possui condições econômicas para sustentar o filho.$uhttps'],
#   'UP': [],
#   'TG': ['Aborto'],
#   'TR': ['Aborto provocado pela gestante ou com seu consentimento'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aborto terapêutico': {'USE': [],
#   'DF': ['Aborto induzido para salvar a vida ou a saúde, física ou mental, de uma mulher grávida.$vDeCS'],
#   'UP': ['Aborto necessário'],
#   'TG': ['Aborto'],
#   'TR': ['Aborto eugênico', 'Aborto sentimental'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abortos eugênicos': {'USE': ['Aborto eugênico'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abortos seletivos': {'USE': ['Aborto eugênico'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aboutness': {'USE': ['Tematicidade (ciência da informação)'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abrasivo': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Mineral'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abreugrafia': {'USE': [],
#   'DF': ['Método\xa0brasileiro\xa0rápido e barato de tirar pequenas chapas radiográficas dos\xa0pulmões, para facilitar o diagnóstico da tuberculose.'],
#   'UP': [],
#   'TG': ['Diagnóstico por imagem'],
#   'TR': ['Pulmão', 'Tuberculose'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abreviatura': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Escrita', 'Paleografia'],
#   'TR': ['Sigla', 'Taquigrafia'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abrigado': {'USE': [],
#   'DF': ['Situação de uma pessoa afetada por dano ou ameaça de dano em sua habitação e que, após realizada a triagem socioeconômica e definida a necessidade, é encaminhada a um abrigo.$vSANTA CATARINA. Secretaria de Estado da Defesa Civil. Glossário da Defesa Civil.'],
#   'UP': [],
#   'TG': [],
#   'TR': ['Abrigo (defesa civil)', 'Criança'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abrigagem': {'USE': ['Abrigo (defesa civil)'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abrigo (defesa civil)': {'USE': [],
#   'DF': ['Local ou instalação que proporciona hospedagem a pessoas necessitadas. Em linguagem militar, local que proporciona proteção contra o fogo (tiros e bombas) e contra as vistas (observação) do inimigo.$vBRASIL. Ministério do Planejamento e Orçamento. Glossário de defesa civil, estudo de riscos e medicina de desastres.'],
#   'UP': ['Abrigagem'],
#   'TG': ['Edifício', 'Indústria da construção civil'],
#   'TR': ['Abrigado', 'Ataque aéreo', 'Bombardeio'],
#   'TE': ['Abrigo provisório'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abrigo provisório': {'USE': [],
#   'DF': ['Abrigo organizado numa instalação fixa e adaptada para esta finalidade, por um período determinado.$vBRASIL. Ministério do Planejamento e Orçamento. Glossário de defesa civil, estudo de riscos e medicina de desastres.'],
#   'UP': ['Abrigo temporário'],
#   'TG': ['Abrigo (defesa civil)'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abrigo temporário': {'USE': ['Abrigo provisório'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abrilada (1832)': {'USE': [],
#   'DF': [],
#   'UP': ['Revolta de Abril de 1832'],
#   'TG': ['Regência Trina Permanente (1831-1835)'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Absenteísmo': {'USE': [],
#   'DF': ['Padrão habitual de ausências no processo de trabalho, dever ou obrigação, seja por falta ou atraso, devido a algum motivo interveniente.$uhttps'],
#   'UP': ['Absentismo',
#    'Ausência de empregado',
#    'Ausência no trabalho',
#    'Falta ao serviço',
#    'Falta ao trabalho'],
#   'TG': ['Comportamento humano', 'Psicologia do trabalho'],
#   'TR': ['Emprego (teoria econômica)',
#    'Falta justificada',
#    'Jornada de trabalho',
#    'Presenteísmo'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Absentismo': {'USE': ['Absenteísmo'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Absolutismo': {'USE': [],
#   'DF': [],
#   'UP': ['Monarquia absoluta'],
#   'TG': ['Regime de governo'],
#   'TR': ['Despotismo', 'Monarquia', 'Patrimonialismo'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Absolvição': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Decisão em matéria penal'],
#   'TR': ['Decisão judicial',
#    'Excludente de ilicitude',
#    'Isenção de pena',
#    'Julgamento',
#    'Processo penal',
#    'Réu',
#    'Sanção penal'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abstenção de opinião': {'USE': [],
#   'DF': ['Opinião modificada expressa quando o auditor não consegue obter evidência de auditoria suficiente e apropriada para fundamentar sua opinião e ele conclui que os possíveis efeitos de distorções não detectadas sobre as demonstrações financeiras, se houver, poderiam ser relevantes, mas não generalizadas; ou, quando em circunstâncias extremamente raras envolvendo diversas incertezas, ele conclui que, independentemente de ter obtido evidência de auditoria suficiente e apropriada sobre cada uma das incertezas, não é possível expressar uma opinião sobre as demonstrações financeiras devido à possível interação das incertezas e seu possível efeito cumulativo sobre essas demonstrações.$vBRASIL. Tribunal de Contas da União. Glossário de termos do controle externo. Brasília'],
#   'UP': [],
#   'TG': ['Opinião modificada'],
#   'TR': ['Auditor', 'Demonstração contábil', 'Evidência de auditoria'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abstenção eleitoral': {'USE': [],
#   'DF': ['Termo usado para definir a não-participação [do eleitor] no ato de votar.$uGlossário TSE'],
#   'UP': [],
#   'TG': ['Participação política'],
#   'TR': ['Democracia',
#    'Eleição',
#    'Eleitorado',
#    'Partido político',
#    'Representação política',
#    'Votação',
#    'Voto facultativo',
#    'Voto obrigatório'],
#   'TE': ['Voto em branco', 'Voto nulo'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abstinência de sexo': {'USE': ['Abstinência sexual'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abstinência sexual': {'USE': [],
#   'DF': [],
#   'UP': ['Abstinência de sexo'],
#   'TG': ['Comportamento sexual'],
#   'TR': ['Anticoncepção', 'Controle da natalidade'],
#   'TE': ['Virgindade'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abstracionismo (arte)': {'USE': ['Arte abstrata'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abstract': {'USE': ['Resumo'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abstracts': {'USE': ['Resumo'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abuso da informática': {'USE': ['Cibercrime'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abuso de álcool': {'USE': ['Alcoolismo'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abuso de autoridade': {'USE': [],
#   'DF': ['A Lei 13.869/2019 assegura que são "crimes de abuso de autoridade, os cometidos por agente público, servidor ou não, que, no exercício de suas funções ou a pretexto de exercê-las, abuse do poder que lhe tenha sido atribuído."'],
#   'UP': [],
#   'TG': ['Crime'],
#   'TR': ['Abuso de poder',
#    'Agente público',
#    'Autoridade administrativa',
#    'Autoridade judiciária',
#    'Autoridade policial',
#    'Autoridade pública',
#    'Excesso de poder',
#    'Função pública',
#    'Ilegalidade',
#    'Mandado de segurança',
#    'Servidor público'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': ['Usar apenas quando se tratar de crime previsto nos artigos 3º e 4º da Lei 4.898/65.']},
#  'Abuso de Cannabis': {'USE': ['Abuso de maconha'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abuso de direito': {'USE': [],
#   'DF': ['Exercício anormal do direito, sem motivo legitimo, sem justa causa, unicamente com o intuito de prejudicar, lesar outrem. A doutrina do abuso do direito salienta que os direitos não são absolutos, mas limitados em sua extensão e submetidos a pressupostos quanto ao seu exercício. Quando um titular de determinado direito não obedece a tais limites, age, em verdade, sem direito. Cessa o direito quando começa o abuso, pois um único ato não pode ser, ao mesmo tempo, conforme o direito e contrário ao direito. O ato praticado com abuso é objetivamente licito, mas subjetivamente injusto, assim caracterizado'],
#   'UP': ['Abuso do direito',
#    'Exercício irregular de direito',
#    'Exercício irregular do direito'],
#   'TG': ['Ato ilícito'],
#   'TR': ['Assédio processual',
#    'Ato protelatório',
#    'Dano processual',
#    'Desconsideração da personalidade jurídica',
#    'Manifesta ilegalidade',
#    'Ouvidoria',
#    'Recurso manifestamente protelatório'],
#   'TE': ['Prática abusiva'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abuso de droga': {'USE': ['Toxicomania'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abuso de fenciclidina': {'USE': [],
#   'DF': ['Mal uso de fenciclidina, com sintomas fisiológicos associados e prejuízo na função social ou ocupacional. (Decs)'],
#   'UP': ['Abuso de PCP',
#    'Abuso de pó de anjo',
#    'Uso indevido de PCP',
#    'Uso indevido de pó de anjo'],
#   'TG': ['Transtorno relacionado ao uso de substâncias'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abuso de Haxixe': {'USE': ['Abuso de maconha'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abuso de inalantes': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Transtorno relacionado ao uso de substâncias'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abuso de incapazes': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Estelionato'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abuso de maconha': {'USE': [],
#   'DF': [],
#   'UP': ['Abuso de Cannabis',
#    'Abuso de Haxixe',
#    'Dependência de Cannabis',
#    'Dependência de Maconha',
#    'Transtorno por abuso de Cannabis',
#    'Transtorno por consumo de Cannabis',
#    'Transtorno relacionado ao uso de Cannabis',
#    'Transtorno relacionado com Cannabis',
#    'Transtornos por abuso de Cannabis',
#    'Transtornos por consumo de Cannabis',
#    'Transtornos por uso de Cannabis',
#    'Transtornos relacionado ao uso de Cannabis',
#    'Transtornos relacionados com Cannabis',
#    'Uso indevido de Cannabis',
#    'Uso indevido de Haxixe'],
#   'TG': ['Transtorno relacionado ao uso de substâncias'],
#   'TR': ['Maconha', 'Uso da maconha'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abuso de PCP': {'USE': ['Abuso de fenciclidina'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abuso de pó de anjo': {'USE': ['Abuso de fenciclidina'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abuso de poder': {'USE': [],
#   'DF': ['Exorbitância dos poderes conferidos. Excesso de mandato. Exercícios de atos não outorgados ou não expressos no mandato ou na procuração. Prática de atos que excedem as atribuições contendas em lei ou que escapam à alçada funcional. Arbitrariedade. Os prejuízos decorrentes do abuso de poder, quando praticados por autoridade pública, devidos aos prejudicados, devem ser ressarcidos pela Fazenda Pública.$vFULGENCIO, Paulo Cesar. Glossário vade mécum'],
#   'UP': ['Exercício arbitrário'],
#   'TG': ['Crime contra a administração da justiça'],
#   'TR': ['Abuso de autoridade',
#    'Arbitrariedade',
#    'Ato ilícito',
#    'Autoridade administrativa',
#    'Autoridade judiciária',
#    'Autoridade policial',
#    'Autoridade pública',
#    'Circunstância agravante',
#    'Mandado de segurança',
#    'Manifesta ilegalidade',
#    'Poder discricionário'],
#   'TE': ['Desvio de poder', 'Excesso de poder'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abuso de poder econômico': {'USE': ['Abuso do poder econômico'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abuso de substâncias por via intravenosa': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Transtorno relacionado ao uso de substâncias'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abuso do direito': {'USE': ['Abuso de direito'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abuso do poder econômico': {'USE': [],
#   'DF': ['São formas de abuso do poder econômico, desde que caracterizadas, isolada ou simultaneamente, situações de'],
#   'UP': ['Abuso de poder econômico'],
#   'TG': ['Crime econômico', 'Crime eleitoral'],
#   'TR': ['Ação de impugnação de mandato eletivo',
#    'Ação de investigação judicial eleitoral',
#    'Cassação de mandato',
#    'Direito constitucional econômico',
#    'Livre concorrência',
#    'Lucro',
#    'Monopólio',
#    'Ordem econômica'],
#   'TE': ['Agiotagem'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abuso na prática de aviação': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Contravenção referente à incolumidade pública'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abuso oral de substâncias': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Transtorno relacionado ao uso de substâncias'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abuso sexual': {'USE': [],
#   'DF': ['Violência\xa0sexual'],
#   'UP': ['Delito sexual'],
#   'TG': ['Crime'],
#   'TR': ['Assédio sexual',
#    'Comportamento sexual',
#    'Crime contra a liberdade sexual',
#    'Pedofilia',
#    'Prostituição infantil',
#    'Relação sexual'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Abuso verbal': {'USE': ['Agressão verbal'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'AC': {'USE': ['Autoridade certificadora'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'AC-raiz': {'USE': ['Autoridade certificadora raiz'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Açambarcador': {'USE': ['Intermediário'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Acampamento de férias': {'USE': ['Colônia de férias'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação': {'USE': ['Ação judicial'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação (economia)': {'USE': ['Ações'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação acessória': {'USE': [],
#   'DF': ['Trata-se de uma ação vinculada à principal, da qual é subsidiária; ela é proposta perante ao mesmo juiz e será processada e julgada pelo juiz da ação principal.'],
#   'UP': [],
#   'TG': ['Processo civil'],
#   'TR': ['Ação principal', 'Oposição (processo civil)', 'Reconvenção'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação acidentária': {'USE': ['Ação de acidente do trabalho'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação afirmativa': {'USE': [],
#   'DF': ['Políticas públicas e privadas voltadas para a concretização do princípio constitucional da igualdade material e a neutralização dos efeitos da discriminação de raça, de gênero, de idade, de origem nacional, e de compleição física. Com o objetivo de colocar todos os membros da sociedade em condições de competição pelos bens da vida considerados essenciais, se faz necessário, muitas vezes, favorecer uns, em detrimento de outros.'],
#   'UP': ['Ação positiva',
#    'Cota racial, política',
#    'Cotas sociais, política',
#    'Discriminação inversa',
#    'Discriminação positiva',
#    'Distribuição de cotas',
#    'Política de cotas',
#    'Programa de ações afirmativas',
#    'Sistema de cotas'],
#   'TG': ['Políticas públicas'],
#   'TR': ['Acessibilidade (direitos humanos)',
#    'Direitos dos grupos vulneráveis',
#    'Discriminação na educação',
#    'Discriminação no emprego',
#    'Discriminação racial',
#    'Discriminação religiosa',
#    'Discriminação sexual',
#    'Discriminação social',
#    'Igualdade de oportunidades',
#    'Inclusão social',
#    'Minoria',
#    'Movimento negro',
#    'Mulher trabalhadora',
#    'Princípio da isonomia'],
#   'TE': ['Cota racial'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação anulatória': {'USE': [],
#   'DF': [],
#   'UP': ['Ação de anulação'],
#   'TG': ['Processo civil'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação ao portador': {'USE': [],
#   'DF': ['Ações que podiam ser negociadas diretamente entre as partes, fora do pregão. Isso criava uma série de problemas'],
#   'UP': [],
#   'TG': ['Ação endossável'],
#   'TR': ['Ação nominativa'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação cambial': {'USE': [],
#   'DF': ['A\xa0ação cambial, no direito brasileiro, é uma\xa0ação executiva típica, que objetiva a cobrança de título cambiário (cheque, nota promissória, letra de câmbio, duplicata etc). O portador tem o direito de acionar todos os obrigados e coobrigados, sem estar adstrito a observar a ordem em que eles se obrigaram.$uhttp'],
#   'UP': ['Ação cambiária'],
#   'TG': ['Ação de cobrança'],
#   'TR': ['Cambial',
#    'Cheque',
#    'Cobrança judicial',
#    'Letra de câmbio',
#    'Nota promissória'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação cambiária': {'USE': ['Ação cambial'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação católica': {'USE': [],
#   'DF': ['Conjunto de movimentos criados pela Igreja Católica no século XX, visando ampliar sua influência na sociedade, através da inclusão de setores específicos do laicado e do fortalecimento da fé religiosa, com base na Doutrina Social da Igreja.'],
#   'UP': [],
#   'TG': ['Movimento social'],
#   'TR': ['Catolicismo',
#    'Democracia cristã',
#    'Igreja e problemas sociais',
#    'Sociologia cristã'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação cautelar': {'USE': ['Processo cautelar'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação cautelar de atentado': {'USE': [],
#   'DF': ['Art. 879. Comete atentado a parte que no curso do processo'],
#   'UP': ['Atentado (processo civil)'],
#   'TG': ['Medida cautelar', 'Processo cautelar'],
#   'TR': ['Arresto',
#    'Imissão na posse',
#    'Penhora',
#    'Sequestro de bens (processo civil)',
#    'Situação fática'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação cível': {'USE': [],
#   'DF': ['Ação através da qual a vítima ou os seus representantes tentam obter uma reparação pelos danos que lhe tenham sido infligidos devido a uma infração.$vEurovoc'],
#   'UP': ['Ação civil', 'Ação judiciária civil', 'Ação processual civil'],
#   'TG': ['Ação judicial'],
#   'TR': ['Direito civil', 'Indenização', 'Reparação do dano'],
#   'TE': ['Ação cominatória',
#    'Ação constitutiva',
#    'Ação de comodato',
#    'Ação de divisão',
#    'Ação declaratória',
#    'Ação demolitória',
#    'Ação discriminatória',
#    'Ação popular',
#    'Ação possessória',
#    'Ação preventiva',
#    'Ação previdenciária',
#    'Ação reivindicatória',
#    'Ação renovatória',
#    'Ação rescisória',
#    'Ação resolutória',
#    'Adjudicação compulsória',
#    'Condição da ação',
#    'Execução judicial',
#    'Reconhecimento do pedido'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação civil': {'USE': ['Ação cível'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação civil pública': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Ação constitucional', 'Ação judicial'],
#   'TR': ['Bens públicos',
#    'Controle difuso de constitucionalidade',
#    'Inquérito civil',
#    'Interesse coletivo',
#    'Interesse transindividual',
#    'Meio ambiente',
#    'Ministério público',
#    'Reparação do dano (direito ambiental)',
#    'Substituição processual',
#    'Termo de ajustamento de conduta'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação coletiva': {'USE': [],
#   'DF': [],
#   'UP': ['Processo coletivo'],
#   'TG': ['Ação judicial', 'Processo trabalhista'],
#   'TR': ['Ação de cumprimento',
#    'Incidente de resolução de demandas repetitivas',
#    'Justiça do trabalho',
#    'Reclamação trabalhista',
#    'Sentença normativa',
#    'Substituição processual'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação comercial': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Ação judicial'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação cominatória': {'USE': [],
#   'DF': [],
#   'UP': ['Ação condenatória', 'Ação de condenação'],
#   'TG': ['Ação cível'],
#   'TR': ['Pretensão cominatória'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação comunitária': {'USE': ['Participação comunitária'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação condenatória': {'USE': ['Ação cominatória'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação conexa': {'USE': ['Ações conexas'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação consignatória': {'USE': ['Ação de consignação em pagamento'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação constitucional': {'USE': [],
#   'DF': ['As ações constitucionais\xa0ou remédios constitucionais são instrumentos à\xa0disposição do operador do Direito para garantir a aplicação da lei. A Constituição trouxe\xa0ao todo seis ações constitucionais'],
#   'UP': ['Remédio constitucional'],
#   'TG': ['Ação judicial'],
#   'TR': [],
#   'TE': ['Ação civil pública',
#    'Ação popular',
#    'Habeas corpus',
#    'Habeas data',
#    'Mandado de injunção',
#    'Mandado de segurança'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação constitutiva': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Ação cível'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação criminal': {'USE': ['Ação penal'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação de acidente do trabalho': {'USE': [],
#   'DF': [],
#   'UP': ['Ação acidentária'],
#   'TG': ['Ação judicial', 'Direito previdenciário'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação de adjudicação compulsória': {'USE': ['Adjudicação compulsória'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação de advocacy': {'USE': ['Advocacy'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação de alimentos': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Ação judicial'],
#   'TR': ['Alimentos (direito de família)',
#    'Pensão alimentícia',
#    'Segredo de justiça'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação de anulação': {'USE': ['Ação anulatória'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação de classe especial': {'USE': [],
#   'DF': ['Tem a função de manutenção do Estado ao menos em parte do controle das empresas que tenham se tornado objeto de privatizações, já que os serviços prestados por essas empresas ainda são responsabilidade do Estado.$vSARUBO, Vitor André Pereira. Golden Share. Jurisway, 2012.'],
#   'UP': ['Ações preferenciais de classe especial', 'Ações privilegiadas'],
#   'TG': ['Ações preferenciais'],
#   'TR': ['Privatização'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação de cobrança': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Ação judicial'],
#   'TR': [],
#   'TE': ['Ação cambial'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação de comodato': {'USE': [],
#   'DF': ['Ação movida pelo comodante contra o comodatário, para obter restituição da coisa emprestada nas mesmas condições em que lhe foi entregue e para lhe exigir perdas e danos, quando for o caso (SILVA, 23. ed., 2004).'],
#   'UP': [],
#   'TG': ['Ação cível'],
#   'TR': ['Comodato', 'Empréstimo'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação de condenação': {'USE': ['Ação cominatória'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação de consignação': {'USE': ['Ação de consignação em pagamento'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação de consignação em pagamento': {'USE': [],
#   'DF': [],
#   'UP': ['Ação consignatória', 'Ação de consignação'],
#   'TG': ['Ação judicial', 'Procedimento especial'],
#   'TR': ['Consignação em pagamento'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação de contrafação': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Ação judicial'],
#   'TR': ['Direito autoral', 'Plágio', 'Reprodução (direito autoral)'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Ação de controle': {'USE': [],
#   'DF': ['Ação de controle é uma generalização dos atos do TCU, conduzida por uma de suas unidades, tendo um ministro relator, buscando investigar aspectos de um objeto de controle, podendo levar a uma decisão (acórdão) e a uma sanção.'],
#   'UP': [],
#   'TG': ['Controle externo'],
#   'TR': [],
#   'TE': ['Ação de controle externo'],
#   'EQ': [],
#   'Nota de escopo': []},
# ...
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alcoolismo': {'USE': [],
#   'DF': ['Doença crônica, primária, com fatores genéticos, psicossociais e ambientais influenciando seu desenvolvimento e manifestações. A doença é geralmente progressiva e fatal. É caracterizada pela falta de controle sobre a bebida, pré-ocupação com a droga álcool, uso de álcool apesar das consequências adversas, e distorções no pensamento, negação notável. Cada um destes sintomas pode ser contínuo ou periódico.$vDeCS'],
#   'UP': ['Abuso de álcool'],
#   'TG': ['Doença crônica', 'Problemas sociais'],
#   'TR': ['Alcoólatra',
#    'Bebida alcoólica',
#    'Embriaguez',
#    'Internação involuntária de dependentes de drogas',
#    'Toxicomania'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': ['Usar para obras que tratem o problema do ponto de vista médico.']},
#  'Alcoolquímica': {'USE': [],
#   'DF': ['A alcoolquímica é apresentada como o conjunto de processos que utiliza o álcool etílico (etanol) como matéria-prima para a fabricação de outros produtos. Este segmento da indústria química poderá vir a substituir a petroquímica, fazendo com que o etanol assuma o lugar do petróleo como matéria-prima.$uhttps'],
#   'UP': ['Indústria alcoolquímica'],
#   'TG': ['Indústria química'],
#   'TR': ['Álcool', 'Etanol como combustível', 'Etileno'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aldeia global': {'USE': ['Sociedade da informação'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aldeia indígena': {'USE': ['Reserva indígena'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alegação': {'USE': ['Alegação de defesa'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alegação de defesa': {'USE': [],
#   'DF': ['Manifestação formal de responsável, chamado ao processo por meio de citação, acerca de irregularidade de que resulte débito em função de dano ao erário.$vBRASIL. Tribunal de Contas da União. Glossário de Termos do Controle Externo. 2013'],
#   'UP': ['Alegação', 'Alegações', 'Defesa (direito)'],
#   'TG': [],
#   'TR': ['Advogado',
#    'Citação',
#    'Comunicação processual',
#    'Contestação',
#    'Defesa de responsável',
#    'Direito de defesa',
#    'Direito de petição',
#    'Rejeição de alegações de defesa'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alegação final': {'USE': ['Alegações finais'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alegações': {'USE': ['Alegação de defesa'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alegações finais': {'USE': [],
#   'DF': ['As alegações finais, também conhecidas como razões finais, dentro da área processual do direito, são as exposições que ambas as partes de um processo realizam após o momento da instrução e, portanto, antes do juiz proferir sua sentença a respeito da lide.$uhttps'],
#   'UP': ['Alegação final', 'Razões finais'],
#   'TG': ['Ato processual'],
#   'TR': ['Contraditório',
#    'Direito de defesa',
#    'Nulidade processual',
#    'Princípio do devido processo legal'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aleijado': {'USE': ['Pessoa com deficiência física'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aleitamento materno': {'USE': [],
#   'DF': ['Amamentação de um lactente no peito da mãe.$vDESCRITORES em Ciências da Saúde.'],
#   'UP': ['Amamentação', 'Lactação'],
#   'TG': ['Nutrição infantil'],
#   'TR': ['Banco de leite humano',
#    'Doação de leite humano',
#    'Lactante',
#    'Lactente',
#    'Leite materno',
#    'Maternidade',
#    'Mulher trabalhadora',
#    'Saúde da mulher'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alemães': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Grupos nacionais'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alergia': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Doença'],
#   'TR': ['Alergologia e imunologia'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alergoimunologia': {'USE': ['Alergologia e imunologia'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alergologia': {'USE': ['Alergologia e imunologia'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alergologia e imunologia': {'USE': [],
#   'DF': ['Especialidade médica que lida com a hipersensibilidade dos indivíduos a substâncias estranhas e proteção contra a infecção ou o distúrbio resultante.$vDeCS'],
#   'UP': ['Alergoimunologia',
#    'Alergologia',
#    'Alergologia e imunologia clínica',
#    'Imunoalergologia',
#    'Imunologia',
#    'Imunologia e Alergologia'],
#   'TG': ['Ciências da vida', 'Medicina'],
#   'TR': ['Alergia', 'Anticorpo'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alergologia e imunologia clínica': {'USE': ['Alergologia e imunologia'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alerta (direito administrativo)': {'USE': [],
#   'DF': ['O alerta possui natureza orientadora, ao contrário da determinação prevista no art. 43, inciso I, da Lei nº 8.443/1992. O alerta não possui natureza coercitiva, podendo-se dizer que se trata de mera advertência ao gestor público, pois seu descumprimento não pode ser usado como fundamento para qualquer ato futuro do TCU.$vBRASIL. Tribunal de Contas da União. TC 021.497/2007-0 Plenário'],
#   'UP': ['Ato administrativo de alerta'],
#   'TG': ['Ação de controle externo'],
#   'TR': ['Gestor público'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alfabetação': {'USE': ['Arranjo alfabético'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alfabetação letra por letra': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Arranjo alfabético'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alfabetação palavra por palavra': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Arranjo alfabético'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alfabetização': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Educação'],
#   'TR': ['Analfabetismo',
#    'Analfabeto',
#    'Classe de alfabetização',
#    'Educação de base'],
#   'TE': ['Alfabetização de adultos'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alfabetização de adultos': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Alfabetização'],
#   'TR': ['Educação de adultos', 'Método Paulo Freire'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alfabetização digital': {'USE': ['Competência no uso de computadores'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alfabetização eletrônica': {'USE': ['Competência no uso de computadores'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alfabetização em informação': {'USE': ['Competência em informação'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alfabetização em tecnologia da informação': {'USE': ['Competência no uso de computadores'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alfabetização informacional': {'USE': ['Competência em informação'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alfabetização tecnológica': {'USE': ['Competência no uso de computadores'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alfabeto': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Notação'],
#   'TR': ['Desenho de letras'],
#   'TE': ['Braille'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alfabeto Braille': {'USE': ['Braille'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alface': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Hortaliça'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alfândega': {'USE': [],
#   'DF': [],
#   'UP': ['Aduana'],
#   'TG': ['Direito alfandegário'],
#   'TR': ['Aeroporto internacional',
#    'Autoridade aduaneira',
#    'Bagagem',
#    'Comércio internacional',
#    'Contrabando',
#    'Controle aduaneiro',
#    'Descaminho',
#    'Porto',
#    'Tarifa alfandegária',
#    'Terminal alfandegado'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alforria': {'USE': [],
#   'DF': ['Ato em que se dava a liberdade a um escravo. No ato da libertação, o escravo recebia um documento denominado carta de alforria.$uhttp'],
#   'UP': ['Carta de alforria',
#    'Cartas de alforria',
#    'Cartas de liberdade',
#    'Certificados de alforria',
#    'Manumissão'],
#   'TG': ['Emancipação', 'Liberdade individual'],
#   'TR': ['Escravidão',
#    'Escravidão no Brasil (1539-1888)',
#    'Escravo',
#    'Trabalho escravo'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alga': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Planta aquática'],
#   'TR': [],
#   'TE': ['Alga marinha'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alga de água salgada': {'USE': ['Alga marinha'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alga marinha': {'USE': [],
#   'DF': [],
#   'UP': ['Alga de água salgada'],
#   'TG': ['Alga'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Algaroba': {'USE': ['Leguminosa'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Álgebra': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Matemática'],
#   'TR': ['Teoria dos conjuntos'],
#   'TE': ['Álgebra de Boole', 'Números'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Álgebra Booleana': {'USE': ['Álgebra de Boole'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Álgebra de Boole': {'USE': [],
#   'DF': [],
#   'UP': ['Álgebra Booleana', 'Álgebra de proposições'],
#   'TG': ['Álgebra'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Álgebra de proposições': {'USE': ['Álgebra de Boole'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Algerianos': {'USE': ['Argelinos'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Algodão': {'USE': [],
#   'DF': [],
#   'UP': ['Algodoeiro'],
#   'TG': ['Planta têxtil'],
#   'TR': ['Cotonicultura',
#    'Fibra têxtil',
#    'Indústria algodoeira',
#    'Indústria têxtil',
#    'Óleo de algodão',
#    'Produto têxtil',
#    'Trabalhador têxtil'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Algodão, cultivo': {'USE': ['Cotonicultura'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Algodão, indústria e comércio': {'USE': ['Indústria algodoeira'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Algodoeiro': {'USE': ['Algodão'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Algoritmo': {'USE': [],
#   'DF': ['Fórmula ou procedimento para resolver um problema ou executar uma tarefa. O algoritmo é um conjunto de etapas em uma ordem muito específica, tal como uma fórmula matemática ou as instruções em um programa de computador$v-BACA.'],
#   'UP': [],
#   'TG': ['Conteúdo da informação'],
#   'TR': ['Fluxograma',
#    'Modelo de recuperação da informação',
#    'Programa de computador'],
#   'TE': ['Algoritmo de convolução',
#    'Algoritmo de otimização',
#    'Algoritmo de reestruturação',
#    'Algoritmo registrado'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Algoritmo criptográfico': {'USE': [],
#   'DF': ['Função matemática utilizada na cifração e na decifração de informações sigilosas, necessariamente nas informações classificadas.'],
#   'UP': [],
#   'TG': ['Lógica matemática'],
#   'TR': ['Assinatura digital',
#    'Cifração (segurança da informação)',
#    'Informação sigilosa',
#    'Resumo criptográfico'],
#   'TE': ['Algoritmo de Estado'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Algoritmo de convolução': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Algoritmo'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Algoritmo de Estado': {'USE': [],
#   'DF': ['Algoritmo criptográfico desenvolvido pelo Estado e não comercializável, para uso exclusivo em interesse do serviço de órgãos ou entidades da administração pública federal, direta e indireta.'],
#   'UP': [],
#   'TG': ['Algoritmo criptográfico'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Algoritmo de otimização': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Algoritmo'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Algoritmo de reestruturação': {'USE': [],
#   'DF': ['Voltado para a reestruturação de programas'],
#   'UP': [],
#   'TG': ['Algoritmo'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Algoritmo registrado': {'USE': [],
#   'DF': ['Função matemática utilizada na cifração e na decifração de informações não classificadas, para uso exclusivo em interesse do serviço de órgãos e entidades da administração pública federal, direta e indireta, cujo código fonte e método de processo sejam passíveis de controle e de auditoria.'],
#   'UP': [],
#   'TG': ['Algoritmo'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Alho': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Hortaliça'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aliança internacional': {'USE': [],
#   'DF': ['Pacto de amizade entre Estados. Tratado entre duas ou mais potências objetivando ajuda recíproca, militar ou não.'],
#   'UP': ['Tratado de aliança'],
#   'TG': ['Relações internacionais', 'Tratado'],
#   'TR': ['Cooperação econômica internacional',
#    'Cooperação internacional',
#    'Cooperação jurídica internacional'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aliança Liberal (1930)': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': ['Primeira República (1889-1930)', 'Revolução (1930)'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': ['Acresentar sempre Brasil como especificador geográfico.']},
#  'Aliança Nacional Libertadora (1935)': {'USE': ['Levante comunista (1935)'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aliança parlamentar': {'USE': ['Aliança política'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aliança partidária': {'USE': ['Bloco parlamentar'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aliança política': {'USE': [],
#   'DF': [],
#   'UP': ['Aliança parlamentar'],
#   'TG': ['Acordo político'],
#   'TR': ['Apoio político',
#    'Bloco parlamentar',
#    'Dissidência política',
#    'Estratégia política',
#    'Negociação política',
#    'Política e governo'],
#   'TE': ['Coligação partidária', 'Federação partidária'],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aliciamento de eleitor': {'USE': [],
#   'DF': ['Prática adotada por candidato, partido ou correligionários de candidato ou de partido, que consiste na tentativa de convencer o eleitor, utilizando-se de meios ilegais, a votar em candidato ou partido diferente daquele em que naturalmente votaria, não fosse a ação de convencimento praticada. É crime eleitoral, previsto no art. 39, § 5º, ll, da Lei nº 9.504/97.$vGlossário do TSE'],
#   'UP': ['Aliciamento eleitoral'],
#   'TG': ['Crime eleitoral'],
#   'TR': ['Comportamento eleitoral', 'Compra de votos', 'Fraude eleitoral'],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aliciamento de trabalhadores de um local para outro do território nacional': {'USE': [],
#   'DF': [],
#   'UP': [],
#   'TG': ['Crime contra a organização do trabalho'],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  'Aliciamento eleitoral': {'USE': ['Aliciamento de eleitor'],
#   'DF': [],
#   'UP': [],
#   'TG': [],
#   'TR': [],
#   'TE': [],
#   'EQ': [],
#   'Nota de escopo': []},
#  ...}

# %% [markdown]
# ### Get and Process results from Models

# %%
df_bert = pd.read_csv(BERT_RESULTS_FILE)
df_tfidf = pd.read_csv(TDIDF_RESULTS_FILE)

def process_topic(topic):
    cleaned_topic = topic.rsplit(" (", 1)[0]
    use_topic = vocab_json[cleaned_topic]['USE']
    if use_topic == []:
        return cleaned_topic
    return use_topic[0]

df_bert['Tópico 1'] = df_bert['Tópico 1'].apply(process_topic)
df_bert['Tópico 2'] = df_bert['Tópico 2'].apply(process_topic)
df_bert['Tópicos 1 e 2'] = df_bert['Tópico 1'] + ' | ' + df_bert['Tópico 2']

df_tfidf['Tópico 1'] = df_tfidf['Tópico 1'].apply(process_topic)
df_tfidf['Tópico 2'] = df_tfidf['Tópico 2'].apply(process_topic)
df_tfidf['Tópicos 1 e 2'] = df_tfidf['Tópico 1'] + ' | ' + df_tfidf['Tópico 2']

# %% [markdown]
# ### Plots - BERT

# %%
# Plotting the data with a title
ax = df_bert['Tópico 1'].value_counts(ascending=True).tail(30).plot(
    kind='barh', figsize=(10, 7), color='blue', fontsize=13)
ax.set_title('Top 30 Tópico 1 (BERT)', fontsize=15) # Adding a title to the plot
plt.show()

# %%
# Plotting the data with a title
ax = df_bert['Tópicos 1 e 2'].value_counts(ascending=True).tail(30).plot(
    kind='barh', figsize=(10, 7), color='blue', fontsize=13)
ax.set_title('Top 30 Tópicos 1 e 2 (BERT)', fontsize=15) # Adding a title to the plot
plt.show()

# %% [markdown]
# ### Plots - TFIDF

# %%
# Plotting the data with a title
ax = df_tfidf['Tópico 1'].value_counts(ascending=True).tail(30).plot(
    kind='barh', figsize=(10, 7), color='blue', fontsize=13)
ax.set_title('Top 30 Tópico 1 (TFIDF)', fontsize=15) # Adding a title to the plot
plt.show()

# %%
# Plotting the data with a title
ax = df_tfidf[df_tfidf['Tópico 1']!= df_tfidf['Tópico 2']]['Tópicos 1 e 2'].value_counts(ascending=True).tail(30).plot(
    kind='barh', figsize=(10, 7), color='blue', fontsize=13)
ax.set_title('Top 30 Tópicos 1 e 2 (TFIDF)', fontsize=15) # Adding a title to the plot
plt.show()
